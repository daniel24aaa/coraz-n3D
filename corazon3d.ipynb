# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('dark_background')

def fn(x,y,z):
    return ((x**2) + 9*(y**2)/4 + (z**2) - 1)**3-(x**2)*(z**3)-9*(y**2)*(z**3)/80
bbox=(-1.2,1.2)
xmin, xmax, ymin, ymax, zmin, zmax = bbox*3

fig = plt.figure(figsize=(3, 4),dpi=600)
ax = fig.add_subplot(111, projection='3d')
A = np.linspace(xmin, xmax, 100)
B = np.linspace(xmin, xmax, 50)
A1,A2 = np.meshgrid(A,A)

for z in B:
    X,Y = A1,A2
    Z = fn(X,Y,z)
    cset = ax.contour(X, Y, Z+z, [z], zdir='z',colors='orange')

for y in B:
    X,Z = A1,A2
    Y = fn(X,y,Z)
    cset = ax.contour(X, Y+y, Z, [y], zdir='y',colors='tomato')

for x in B:
    Y,Z = A1,A2
    X = fn(x,Y,Z)
    cset = ax.contour(X+x, Y, Z, [x], zdir='x',colors='crimson')

ax.set_zlim3d(zmin,zmax)
ax.set_xlim3d(xmin,xmax)
ax.set_ylim3d(ymin,ymax)
plt.axis('off')
fig.savefig('Corazón3D_1.jpg',dpi=3000)
#plt.axis('off')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10440/3260007248.py:20: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z',colors='orange')
# C:\Users\User\AppData\Local\Temp/ipykernel_10440/3260007248.py:25: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y+y, Z, [y], zdir='y',colors='tomato')
# C:\Users\User\AppData\Local\Temp/ipykernel_10440/3260007248.py:30: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x',colors='crimson')
